# %%
#Dependencies and Data
import pandas as pd

stats_10s = pd.read_csv("../data/stats_10s.csv")

stats_10s.head()
# Out:
#   Unnamed: 0 abbreviation  assists  blocks  defensive_rebounds  \
# 0        PHO          PHO     1912     418                2616
# 1        GSW          GSW     1839     340                2397
# 2        DEN          DEN     1719     417                2505
# 3        UTA          UTA     2187     400                2588
# 4        TOR          TOR     1804     384                2507
#
#    field_goal_attempts  field_goal_percentage  field_goals  \
# 0                 6788                  0.492         3339
# 1                 7094                  0.469         3329
# 2                 6678                  0.468         3124
# 3                 6575                  0.491         3227
# 4                 6631                  0.482         3199
#
#    free_throw_attempts  free_throw_percentage  ...  steals  \
# 0                 2117                  0.770  ...     479
# 1                 2085                  0.782  ...     761
# ...
