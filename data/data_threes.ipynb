# %%
#Dependencies
import pandas as pd
from sportsreference.nba.teams import Teams

# %%
#Importing stats from the 2019-2020 NBA Season *A full regular season was not played due to Covid-19*
teams = Teams("2020")

stats_19_20 = teams.dataframes
stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1849     363                2729                 6772
# MIL          MIL     1889     429                3083                 6638
# POR          POR     1525     451                2599                 6749
# HOU          HOU     1557     371                2484                 6512
# LAC          LAC     1708     338                2664                 6425
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.461         3124                 1787
# MIL                  0.476         3160                 1800
# POR                  0.463         3122                 1632
# HOU                  0.451         2936                 1876
# LAC                  0.466         2992                 1894
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.779         1392  ...     1     460
# ...

# %%
#subsetting for three point values
#
threes_20 = stats_19_20[['three_point_field_goal_attempts', 'three_point_field_goal_percentage',
       'three_point_field_goals', "games_played"]].copy()
threes_20
# Out:
#      three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                             3095                              0.367
# MIL                             2840                              0.355
# POR                             2525                              0.377
# HOU                             3261                              0.345
# LAC                             2410                              0.371
# NOP                             2656                              0.370
# PHO                             2320                              0.358
# WAS                             2345                              0.368
# MEM                             2297                              0.347
# BOS                             2487                              0.364
# MIA                             2584                              0.379
# DEN                             2234                              0.359
# ...

# %%
#creating a new column for avg attempts/makes per game
threes_20["three_point_field_goal_attempts_per_game"] = round(threes_20["three_point_field_goal_attempts"] / threes_20["games_played"],2)
threes_20["three_point_field_goals_per_game"] = round(threes_20["three_point_field_goals"] / threes_20["games_played"],2)

threes_20
# Out:
#      three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                             3095                              0.367
# MIL                             2840                              0.355
# POR                             2525                              0.377
# HOU                             3261                              0.345
# LAC                             2410                              0.371
# NOP                             2656                              0.370
# PHO                             2320                              0.358
# WAS                             2345                              0.368
# MEM                             2297                              0.347
# BOS                             2487                              0.364
# MIA                             2584                              0.379
# DEN                             2234                              0.359
# ...

# %%
#summary statistics for the 2019-2020 season for 3s
threes_20.describe()
# Out:
#        three_point_field_goal_attempts  three_point_field_goal_percentage  \
# count                        30.000000                          30.000000
# mean                       2408.400000                           0.357767
# std                         311.154979                           0.014127
# min                        1872.000000                           0.333000
# 25%                        2231.750000                           0.347250
# 50%                        2349.500000                           0.358500
# 75%                        2539.250000                           0.368000
# max                        3261.000000                           0.380000
#
#        three_point_field_goals  games_played  \
# count                30.000000     30.000000
# mean                862.066667     70.600000
# std                 120.013486      3.328042
# min                 631.000000     64.000000
# 25%                 786.500000     68.000000
# ...

# %%
#nba data over the last 10 years
year = 2010

for i in range(10):
    year = str(year)
    new_year = Teams(year)
    new_year = new_year.dataframes
    new_year["year"] = year

    if year == "2010":
        stats_10s = new_year
    else:
        stats_10s = pd.concat([stats_10s,new_year])
        
    year = int(year)
    year += 1

stats_10s.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# PHO          PHO     1912     418                2616                 6788
# GSW          GSW     1839     340                2397                 7094
# DEN          DEN     1719     417                2505                 6678
# UTA          UTA     2187     400                2588                 6575
# TOR          TOR     1804     384                2507                 6631
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# PHO                  0.492         3339                 2117
# GSW                  0.469         3329                 2085
# DEN                  0.468         3124                 2508
# UTA                  0.491         3227                 2233
# TOR                  0.482         3199                 2118
#
#      free_throw_percentage  free_throws  ...  steals  \
# PHO                  0.770         1631  ...     479
# ...

# %%
#data summary
stats_10s.describe()
# Out:
#            assists      blocks  defensive_rebounds  field_goal_attempts  \
# count   300.000000  300.000000          300.000000           300.000000
# mean   1791.880000  393.016667         2595.863333          6742.286667
# std     212.824528   63.029454          247.250049           525.457009
# min    1224.000000  195.000000         1879.000000          5086.000000
# 25%    1689.000000  347.000000         2477.000000          6638.000000
# 50%    1795.500000  387.500000         2628.000000          6844.500000
# 75%    1917.000000  436.000000         2774.500000          7051.500000
# max    2491.000000  624.000000         3316.000000          7706.000000
#
#        field_goal_percentage  field_goals  free_throw_attempts  \
# count             300.000000   300.000000           300.000000
# mean                0.455493  3071.810000          1859.843333
# std                 0.015521   268.489022           230.314759
# min                 0.408000  2193.000000          1198.000000
# ...

# %%
#writing to csv
stats_10s.to_csv("../data/stats_10s.csv")
